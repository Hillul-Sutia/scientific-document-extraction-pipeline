# %%
import json
import pandas as pd

# %% [markdown]
# # **Extracted Data**

# %% [markdown]
# ## **Food Id name Mapping**

# %%
food_ids_path = r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\tables\food_ids.json"

with open(food_ids_path, "r", encoding="utf-8") as f:
    data = json.load(f)

# %%
data[:3]
# Out:
# [{'food_id': 'F0001',
#   'food_name': '_lactobacillus spicheri_ g2',
#   'aliases': ['_lactobacillus spicheri_ g2']},
#  {'food_id': 'F0002', 'food_name': '_namsing_', 'aliases': ['_namsing_']},
#  {'food_id': 'F0003',
#   'food_name': 'african or european traditional cultured milks',
#   'aliases': ['african or european traditional cultured milks']}]

# %%
len(data)
# Out:
# 83

# %%
food_ids_df = pd.DataFrame(data)
food_ids_df
# Out:
#    food_id                                       food_name  \
# 0    F0001                     _lactobacillus spicheri_ g2
# 1    F0002                                       _namsing_
# 2    F0003  african or european traditional cultured milks
# 3    F0004                   akhuni (fermented soya beans)
# 4    F0005                                    akhuni/axone
# ..     ...                                             ...
# 78   F0079                                    utonga-kupsu
# 79   F0080                                 wet/pulp/smoked
# 80   F0081                                             zao
# 81   F0082                                       ziang dui
# 82   F0083                                      ziang sang
#
#                                              aliases
# 0                      [_lactobacillus spicheri_ g2]
# 1                                        [_namsing_]
# 2   [african or european traditional cultured milks]
# ...

# %% [markdown]
# ## **Table 1**

# %%
t1 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\tables\table1.json")
t1
# Out:
#    food_id                                       food_name  \
# 0    F0001                     _lactobacillus spicheri_ g2
# 1    F0002                                       _namsing_
# 2    F0003  african or european traditional cultured milks
# 3    F0004                   akhuni (fermented soya beans)
# 4    F0005                                    akhuni/axone
# ..     ...                                             ...
# 78   F0079                                    utonga-kupsu
# 79   F0080                                 wet/pulp/smoked
# 80   F0081                                             zao
# 81   F0082                                       ziang dui
# 82   F0083                                      ziang sang
#
#                category                   type               ethnic_group  \
# 0   Fermented Vegetable   Solid Fermented Food                       None
# 1        Fermented Fish   Solid Fermented Food  Mising community of Assam
# ...

# %%
len(t1['food_id'])
# Out:
# 83

# %%
t1['category'].value_counts()
# Out:
# category
# Fermented Vegetable        41
# Fermented Fish             22
# Fermented Beverage          9
# Fermented Dairy             5
# Solid Fermented Food        1
# Fermented Fish Products     1
# Fermented Soybean           1
# Fermented Meat and Fish     1
# Name: count, dtype: int64

# %%
t1['type'].value_counts()
# Out:
# type
# Solid Fermented Food                65
# Liquid Fermented Food               11
# Non-alcoholic Fermented Beverage     3
# Fermented Beverage                   1
# Alcoholic Fermented Beverage         1
# Name: count, dtype: int64

# %%
t1['ethnic_group'].value_counts()
# Out:
# ethnic_group
# Northeast India                  25
# Naga                              5
# Garo tribe                        3
# Mising community of Assam         1
# Sümi tribe                        1
# Barman community                  1
# People of Northeast India         1
# Assam                             1
# Dimasa Kachari community          1
# Thai                              1
# Manipur                           1
# Meiteilon                         1
# Lotha Naga tribe of Nagaland      1
# Arunachal Pradesh and Manipur     1
# Name: count, dtype: int64

# %%
ethnic_group_col_val = t1['ethnic_group'].to_list()
ethnic_group_col_val = [ str(e).split(',') for e in ethnic_group_col_val]
ethnic_group = []

for e in ethnic_group_col_val:
    ethnic_group.extend(e)
ethnic_group = [ e.strip() for e in ethnic_group ]
ethnic_group,len(ethnic_group)
# Out:
# (['None',
#   'Mising community of Assam',
#   'Northeast India',
#   'Sümi tribe',
#   'Naga',
#   'None',
#   'None',
#   'None',
#   'Northeast India',
#   'None',
#   'None',
#   'Barman community',
#   'Northeast India',
#   'People of Northeast India',
#   'None',
#   'None',
#   'Assam',
#   'Northeast India',
#   'Northeast India',
#   'Northeast India',
#   'Northeast India',
#   'None',
#   'None',
#   'Northeast India',
#   'Naga',
#   'Northeast India',
#   'Northeast India',
#   'Northeast India',
#   'None',
#   'None',
#   'Northeast India',
#   'Garo tribe',
#   'None',
#   'None',
#   'None',
#   'None',
#   'Naga',
#   'None',
#   'None',
#   'Dimasa Kachari community',
#   'None',
#   'None',
#   'Northeast India',
#   'None',
#   'None',
#   'None',
#   'None',
#   'Northeast India',
#   'Northeast India',
#   'Thai',
#   'None',
#   'None',
#   'Northeast India',
#   'None',
#   'Northeast India',
#   'None',
#   'Garo tribe',
#   'Naga',
#   'Northeast India',
# ...

# %%
ethnic_group_set = set(ethnic_group)
ethnic_group_set,len(ethnic_group_set)
# Out:
# ({'Arunachal Pradesh and Manipur',
#   'Assam',
#   'Barman community',
#   'Dimasa Kachari community',
#   'Garo tribe',
#   'Lotha Naga tribe of Nagaland',
#   'Manipur',
#   'Meiteilon',
#   'Mising community of Assam',
#   'Naga',
#   'None',
#   'Northeast India',
#   'People of Northeast India',
#   'Sümi tribe',
#   'Thai'},
#  15)

# %% [markdown]
# ## **Table 2**

# %%
t2 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\tables\table2.json")
t2
# Out:
#    food_id                                       food_name  \
# 0    F0002                                       _namsing_
# 1    F0003  african or european traditional cultured milks
# 2    F0003  african or european traditional cultured milks
# 3    F0004                   akhuni (fermented soya beans)
# 4    F0004                   akhuni (fermented soya beans)
# ..     ...                                             ...
# 84   F0076                            traditional sausages
# 85   F0077                                      tungrymbai
# 86   F0078                                         tungtap
# 87   F0078                                         tungtap
# 88   F0080                                 wet/pulp/smoked
#
#                                    evidence_chunk_ids  \
# 0   [Indigenous_fermented_foods_of_Northeast_India...
# 1   [Ethnic_fermentation_secrets_of_Northeast_Indi...
# 2   [Ethnic_fermentation_secrets_of_Northeast_Indi...
# ...

# %%
t2['raw_material'].value_counts()
# Out:
# raw_material
# fermented bamboo shoot                                 7
# bamboo shoot                                           5
# phabou (P. sophore)                                    4
# fish                                                   3
# Ngari                                                  3
# fermented soya beans and some bamboo shoot             2
# Shidal                                                 2
# LAByeast consortia or kefir grains                     2
# Hawaijar                                               2
# humao                                                  2
# Seedal                                                 2
# phabou                                                 2
# areca nut                                              2
# fermented bamboo shoot (wet/pulp/smoked)               2
# tender bamboo shoot                                    2
# defined inoculum of _B. subtilis_ var. _natto_         2
# ...

# %% [markdown]
# ## **Table 3**

# %%
t3 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\verification\verified\table3.json")
t3
# Out:
#    food_id                      food_name  \
# 0    F0002                      _namsing_
# 1    F0004  akhuni (fermented soya beans)
# 2    F0005                   akhuni/axone
# 3    F0006                         anishi
# 4    F0006                         anishi
# 5    F0010                     baiya nigu
# 6    F0011                   bamboo shoot
# 7    F0012               barman community
# 8    F0013                         cheese
# 9    F0021                fermented foods
# 10   F0022        fermented mustard seeds
# 11   F0025           fermented yam leaves
# 12   F0025           fermented yam leaves
# 13   F0026                     fish paste
# 14   F0027                     fish sauce
# 15   F0032                        hentaak
# 16   F0037                    inziangsang
# 17   F0039              japanese shiokara
# 18   F0040                         judima
# 19   F0040                         judima
# 20   F0041               kahudi/panitenga
# ...

# %%
t3['state'].value_counts()
# Out:
# state
# New Delhi            1
# Arunachal Pradesh    1
# Nagaland             1
# Name: count, dtype: int64

# %%
t3['district'].value_counts()
# Out:
# Series([], Name: count, dtype: int64)

# %%
t3['ethnic_group'].value_counts()
# Out:
# ethnic_group
# Northeast India                                  6
# Naga                                             5
# Khasis                                           5
# Garo tribe                                       5
# tribal communities of Northeast India            4
# Northeast Indian women                           3
# Naga women                                       2
# Lotha Naga community                             2
# Manipur                                          1
# Tea tribes                                       1
# Karbi tribes                                     1
# Lotha Naga tribe of Nagaland                     1
# Garo tribes                                      1
# Mising community of Assam                        1
# Assam and the surrounding Northeastern states    1
# Karbi community                                  1
# Dimasa Kachari                                   1
# Sümi tribe                                       1
# ...

# %%
t3['village'].value_counts()
# Out:
# village
# Dimapur                                      1
# Manipur and Nagaland                         1
# Judima                                       1
# Moinapara village                            1
# Kuki household in Karbi Anglong              1
# Ngari (fermented fish product of Manipur)    1
# Manipur                                      1
# Phabou (P. sophore)                          1
# Hor Alank                                    1
# Haria                                        1
# Tungtap                                      1
# Name: count, dtype: int64

# %%
len(t3)
# Out:
# 50

# %% [markdown]
# ## **Table 4: Nutrition**

# %%
t4 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\tables\table4.json")
t4
# Out:
#   food_id               food_name  \
# 0   F0018  fermented bamboo shoot
# 1   F0018  fermented bamboo shoot
# 2   F0018  fermented bamboo shoot
# 3   F0057             na.kam su.a
#
#                                   evidence_chunk_ids               category  \
# 0  [BambooShootinourBlood_c00015_57ed4e30, Bamboo...  Proximate Composition
# 1            [BambooShootinourBlood_c00015_57ed4e30]  Proximate Composition
# 2            [BambooShootinourBlood_c00015_57ed4e30]  Proximate Composition
# 3  [Traditional_preparation_of_Na_kam_su_a_-_an_e...  Proximate Composition
#
#           parameter                  value  unit  \
# 0              sour                 strong
# 1         sweetness                 strong
# 2              sour  way too strong for me
# 3  moisture content                 36.82%  None
#
#                                evidence_verification  \
# 0  {'status': 'verified_with_derived_fields', 'fi...
# 1  {'status': 'verified_with_derived_fields', 'fi...
# ...

# %%
t4['category'].value_counts()
# Out:
# category
# Proximate Composition    4
# Name: count, dtype: int64

# %%
t4['parameter'].value_counts()
# Out:
# parameter
# sour                2
# sweetness           1
# moisture content    1
# Name: count, dtype: int64

# %% [markdown]
# ## **Table 5**

# %%
t5 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\tables\table5.json")
t5.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
t5['moisture'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 t5['moisture'].value_counts()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'moisture'

# %%
t5['ash'].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 t5['ash'].value_counts()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:4113, in DataFrame.__getitem__(self, key)
#    4111 if self.columns.nlevels > 1:
#    4112     return self._getitem_multilevel(key)
# -> 4113 indexer = self.columns.get_loc(key)
#    4114 if is_integer(indexer):
#    4115     indexer = [indexer]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\range.py:417, in RangeIndex.get_loc(self, key)
#     415         raise KeyError(key) from err
#     416 if isinstance(key, Hashable):
# --> 417     raise KeyError(key)
#     418 self._check_indexing_error(key)
#     419 raise KeyError(key)
#
# KeyError: 'ash'

# %% [markdown]
# ## **Table 6**

# %%
t6 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\tables\table6.json")
t6
# Out:
#    food_id                       food_name  \
# 0    F0005                    akhuni/axone
# 1    F0005                    akhuni/axone
# 2    F0005                    akhuni/axone
# 3    F0005                    akhuni/axone
# 4    F0005                    akhuni/axone
# 5    F0006                          anishi
# 6    F0009                   bacillus spp.
# 7    F0014                  chinese douchi
# 8    F0019         fermented bamboo shoots
# 9    F0019         fermented bamboo shoots
# 10   F0019         fermented bamboo shoots
# 11   F0020         fermented fish products
# 12   F0020         fermented fish products
# 13   F0023         fermented pork products
# 14   F0026                      fish paste
# 15   F0031                        hawaijar
# 16   F0031                        hawaijar
# 17   F0033                          hentak
# 18   F0033                          hentak
# 19   F0034                           hilsa
# 20   F0037                     inziangsang
# ...

# %%
t6['taxonomy_level'].value_counts()
# Out:
# taxonomy_level
# genus      32
# species    22
# Name: count, dtype: int64

# %%
t6['taxonomy_name'].value_counts()
# Out:
# taxonomy_name
# Bacillus spp.                    4
# Bacillus subtilis                4
# _S. cerevisiae                   3
# _Lactobacillus_                  3
# _Weissella_                      3
# _Bacillus_                       3
# _Bacillus subtilis_              3
# _Staphylococcus nepalensis_      3
# _Leuconostoc_                    3
# _Bacillus                        3
# _Staphylococcus                  2
# Aspergillus oryzae               2
# Pediococcus                      2
# Lactobacillus                    2
# soidon                           1
# Setipinna phasa                  1
# Staphylococcus                   1
# ngawum                           1
# _Satipinna phasa_                1
# Bacillus                         1
# Micrococcus                      1
# axone                            1
# _Aspergillus                     1
# Bacillus sp. KA38                1
# Bacillus amyloliquefaciens       1
# lung seij                        1
# ...

# %%
t6[t6['taxonomy_level'] == 'genus']
# Out:
#    food_id                food_name  \
# 1    F0005             akhuni/axone
# 2    F0005             akhuni/axone
# 3    F0005             akhuni/axone
# 4    F0005             akhuni/axone
# 8    F0019  fermented bamboo shoots
# 9    F0019  fermented bamboo shoots
# 10   F0019  fermented bamboo shoots
# 11   F0020  fermented fish products
# 12   F0020  fermented fish products
# 14   F0026               fish paste
# 15   F0031                 hawaijar
# 16   F0031                 hawaijar
# 17   F0033                   hentak
# 18   F0033                   hentak
# 28   F0053                     miso
# 29   F0053                     miso
# 30   F0053                     miso
# 34   F0059                    natto
# 36   F0061                    ngari
# 37   F0061                    ngari
# 38   F0061                    ngari
# 41   F0063     rice beer probiotics
# 42   F0063     rice beer probiotics
# 43   F0063     rice beer probiotics
# 44   F0065                   salami
# ...

# %%
t6[
    (t6['taxonomy_level'] == 'species') &
    (t6['taxonomy_name'].str.split().str.len() == 1)
]
# Out:
#    food_id     food_name                                 evidence_chunk_ids  \
# 0    F0005  akhuni/axone  [BambooShootinourBlood_c00012_1dafbfa6, Bamboo...
# 22   F0048        kimchi  [Ethnic_fermentation_secrets_of_Northeast_Indi...
# 23   F0048        kimchi  [Ethnic_fermentation_secrets_of_Northeast_Indi...
# 24   F0048        kimchi  [Ethnic_fermentation_secrets_of_Northeast_Indi...
# 47   F0071        soidon  [BambooShootinourBlood_c00003_3d8cb56a, Bamboo...
#
#    taxonomy_level    taxonomy_name  \
# 0         species            axone
# 22        species    _Leuconostoc_
# 23        species  _Lactobacillus_
# 24        species      _Weissella_
# 47        species           soidon
#
#                                 evidence_verification  \
# 0   {'status': 'verified_with_derived_fields', 'fi...
# 22  {'status': 'verified_exact_or_normalized', 'fi...
# 23  {'status': 'verified_exact_or_normalized', 'fi...
# 24  {'status': 'verified_exact_or_normalized', 'fi...
# ...

# %% [markdown]
# ## **Table 7**

# %%
t7 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\tables\table7.json")
t7
# Out:
#    food_id                      food_name  \
# 0    F0002                      _namsing_
# 1    F0002                      _namsing_
# 2    F0004  akhuni (fermented soya beans)
# 3    F0006                         anishi
# 4    F0008                      areca nut
# ..     ...                            ...
# 77   F0082                      ziang dui
# 78   F0082                      ziang dui
# 79   F0083                     ziang sang
# 80   F0083                     ziang sang
# 81   F0083                     ziang sang
#
#                                    evidence_chunk_ids  \
# 0   [Indigenous_fermented_foods_of_Northeast_India...
# 1   [Indigenous_fermented_foods_of_Northeast_India...
# 2   [BambooShootinourBlood_c00014_ff4f1c86, Bamboo...
# 3   [BambooShootinourBlood_c00012_1dafbfa6, Bamboo...
# 4   [Ethnic_fermentation_secrets_of_Northeast_Indi...
# ..                                                ...
# 77                  [Northeast_India_c00010_24a2beee]
# ...

# %%
t7
# Out:
#    food_id                      food_name  \
# 0    F0002                      _namsing_
# 1    F0002                      _namsing_
# 2    F0004  akhuni (fermented soya beans)
# 3    F0006                         anishi
# 4    F0008                      areca nut
# ..     ...                            ...
# 77   F0082                      ziang dui
# 78   F0082                      ziang dui
# 79   F0083                     ziang sang
# 80   F0083                     ziang sang
# 81   F0083                     ziang sang
#
#                                    evidence_chunk_ids  \
# 0   [Indigenous_fermented_foods_of_Northeast_India...
# 1   [Indigenous_fermented_foods_of_Northeast_India...
# 2   [BambooShootinourBlood_c00014_ff4f1c86, Bamboo...
# 3   [BambooShootinourBlood_c00012_1dafbfa6, Bamboo...
# 4   [Ethnic_fermentation_secrets_of_Northeast_Indi...
# ..                                                ...
# 77                  [Northeast_India_c00010_24a2beee]
# ...

# %% [markdown]
# # **Verified**

# %%
t1 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\verification\verified\table1.json")
t1
# Out:
#    food_id                                       food_name  \
# 0    F0001                     _lactobacillus spicheri_ g2
# 1    F0002                                       _namsing_
# 2    F0003  african or european traditional cultured milks
# 3    F0004                   akhuni (fermented soya beans)
# 4    F0005                                    akhuni/axone
# ..     ...                                             ...
# 77   F0079                                    utonga-kupsu
# 78   F0080                                 wet/pulp/smoked
# 79   F0081                                             zao
# 80   F0082                                       ziang dui
# 81   F0083                                      ziang sang
#
#                category                   type               ethnic_group  \
# 0   Fermented Vegetable   Solid Fermented Food                       None
# 1        Fermented Fish   Solid Fermented Food  Mising community of Assam
# ...

# %%
t2 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\verification\verified\table2.json")
t2
# Out:
#    food_id                                       food_name  \
# 0    F0002                                       _namsing_
# 1    F0003  african or european traditional cultured milks
# 2    F0003  african or european traditional cultured milks
# 3    F0004                   akhuni (fermented soya beans)
# 4    F0004                   akhuni (fermented soya beans)
# ..     ...                                             ...
# 84   F0076                            traditional sausages
# 85   F0077                                      tungrymbai
# 86   F0078                                         tungtap
# 87   F0078                                         tungtap
# 88   F0080                                 wet/pulp/smoked
#
#                                    evidence_chunk_ids  \
# 0   [Indigenous_fermented_foods_of_Northeast_India...
# 1   [Ethnic_fermentation_secrets_of_Northeast_Indi...
# 2   [Ethnic_fermentation_secrets_of_Northeast_Indi...
# ...

# %%
t3 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\verification\verified\table3.json")
t3
# Out:
#    food_id                      food_name  \
# 0    F0002                      _namsing_
# 1    F0004  akhuni (fermented soya beans)
# 2    F0005                   akhuni/axone
# 3    F0006                         anishi
# 4    F0006                         anishi
# 5    F0010                     baiya nigu
# 6    F0011                   bamboo shoot
# 7    F0012               barman community
# 8    F0013                         cheese
# 9    F0021                fermented foods
# 10   F0022        fermented mustard seeds
# 11   F0025           fermented yam leaves
# 12   F0025           fermented yam leaves
# 13   F0026                     fish paste
# 14   F0027                     fish sauce
# 15   F0032                        hentaak
# 16   F0037                    inziangsang
# 17   F0039              japanese shiokara
# 18   F0040                         judima
# 19   F0040                         judima
# 20   F0041               kahudi/panitenga
# ...

# %%
t4 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\verification\verified\table4.json")
t4
# Out:
#   food_id               food_name  \
# 0   F0018  fermented bamboo shoot
# 1   F0018  fermented bamboo shoot
# 2   F0018  fermented bamboo shoot
# 3   F0057             na.kam su.a
#
#                                   evidence_chunk_ids               category  \
# 0  [BambooShootinourBlood_c00015_57ed4e30, Bamboo...  Proximate Composition
# 1            [BambooShootinourBlood_c00015_57ed4e30]  Proximate Composition
# 2            [BambooShootinourBlood_c00015_57ed4e30]  Proximate Composition
# 3  [Traditional_preparation_of_Na_kam_su_a_-_an_e...  Proximate Composition
#
#           parameter                  value  unit  \
# 0              sour                 strong
# 1         sweetness                 strong
# 2              sour  way too strong for me
# 3  moisture content                 36.82%  None
#
#                                evidence_verification  \
# 0  {'status': 'verified_with_derived_fields', 'fi...
# 1  {'status': 'verified_with_derived_fields', 'fi...
# ...

# %%
t5 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\verification\verified\table5.json")
t5.head()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
t6 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\verification\verified\table6.json")
t6
# Out:
#    food_id                       food_name  \
# 0    F0005                    akhuni/axone
# 1    F0005                    akhuni/axone
# 2    F0005                    akhuni/axone
# 3    F0005                    akhuni/axone
# 4    F0005                    akhuni/axone
# 5    F0006                          anishi
# 6    F0009                   bacillus spp.
# 7    F0014                  chinese douchi
# 8    F0019         fermented bamboo shoots
# 9    F0019         fermented bamboo shoots
# 10   F0019         fermented bamboo shoots
# 11   F0020         fermented fish products
# 12   F0020         fermented fish products
# 13   F0023         fermented pork products
# 14   F0026                      fish paste
# 15   F0031                        hawaijar
# 16   F0031                        hawaijar
# 17   F0033                          hentak
# 18   F0033                          hentak
# 19   F0034                           hilsa
# 20   F0037                     inziangsang
# ...

# %%
t7 = pd.read_json(r"E:\HILLUL\Project Associate - I\SDEP\ubuntu_logs\10 pdfs\data\verification\verified\table7.json")
t7
# Out:
#    food_id                      food_name  \
# 0    F0002                      _namsing_
# 1    F0002                      _namsing_
# 2    F0004  akhuni (fermented soya beans)
# 3    F0006                         anishi
# 4    F0008                      areca nut
# ..     ...                            ...
# 77   F0082                      ziang dui
# 78   F0082                      ziang dui
# 79   F0083                     ziang sang
# 80   F0083                     ziang sang
# 81   F0083                     ziang sang
#
#                                    evidence_chunk_ids  \
# 0   [Indigenous_fermented_foods_of_Northeast_India...
# 1   [Indigenous_fermented_foods_of_Northeast_India...
# 2   [BambooShootinourBlood_c00014_ff4f1c86, Bamboo...
# 3   [BambooShootinourBlood_c00012_1dafbfa6, Bamboo...
# 4   [Ethnic_fermentation_secrets_of_Northeast_Indi...
# ..                                                ...
# 77                  [Northeast_India_c00010_24a2beee]
# ...
